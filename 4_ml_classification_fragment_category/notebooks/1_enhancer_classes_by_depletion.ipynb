# %% [markdown]
# # Motifs that were enriched in categorized fragments responding to the depletion

# %%
import os
import numpy as np
import pandas as pd

# %%
def get_top_features(filename, ntop=10):
    top_features_df = pd.read_csv(filename, header=None)
    return top_features_df.loc[:ntop-1, 0].to_list()

def get_scores(filename):
    return pd.read_csv(filename).T

# %% [markdown]
# # Top 10 motifs for each ko lines by enhancer category

# %%
categories = ["peaks_vs_notpeaks", "responsive_vs_nonresponsive", "induced_vs_repressed"]
ko_lines = ["ATF2", "CTCF", "FOXA1", "LEF1", "SCRT1", "TCF7L2", "16P12_1"]
store_dir = "../data/"

def get_feature_file(store_dir, ko, cat):
    filen = os.path.join(store_dir, ko, cat, "features.csv")
    return filen

def get_score_file(store_dir, ko, cat):
    filen = os.path.join(store_dir, ko, cat, "scores.csv")
    return filen

def create_ko_specific_df(store_dir, ko, categories):
    data_dict = {f"{c}":[] for c in categories}
    score_sers = []
    for c in categories:
        feature_file = get_feature_file(store_dir, ko, c)
        features = get_top_features(feature_file)
        data_dict[f"{c}"] = features
        score_file = get_score_file(store_dir, ko, c)
        score_ser = get_scores(score_file)
        score_sers.append(score_ser)
    features_df = pd.DataFrame(data=data_dict, columns=categories)
    score_df = pd.concat(score_sers, axis=1)
    score_df.columns = categories
    return features_df, score_df

# %% [markdown]
# # ATF2

# %%
atf2_features_df, atf2_scores_df = create_ko_specific_df(store_dir, ko_lines[0], categories)

# %%
atf2_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive    induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|+   ZFX_HUMAN.H11MO.0.A|-
# 1    P53_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|-   ZFX_HUMAN.H11MO.0.A|+
# 2    P63_HUMAN.H11MO.0.A|-      ATF4_HUMAN.H11MO.0.A|-   P53_HUMAN.H11MO.0.A|+
# 3    P63_HUMAN.H11MO.0.A|+       P63_HUMAN.H11MO.0.A|-   P53_HUMAN.H11MO.0.A|-
# 4   ATF4_HUMAN.H11MO.0.A|+      ATF4_HUMAN.H11MO.0.A|+  ATF4_HUMAN.H11MO.0.A|+
# 5  CREB1_HUMAN.H11MO.0.A|-     CEBPG_HUMAN.H11MO.0.B|-   P63_HUMAN.H11MO.0.A|-
# 6  CEBPG_HUMAN.H11MO.0.B|-      ETS2_HUMAN.H11MO.0.B|+  NFIA_HUMAN.H11MO.0.C|+
# 7   TYY1_HUMAN.H11MO.0.A|+       SUH_HUMAN.H11MO.0.A|+   P63_HUMAN.H11MO.0.A|+
# 8    P73_HUMAN.H11MO.0.A|+     IKZF1_HUMAN.H11MO.0.C|-  ATF4_HUMAN.H11MO.0.A|-
# 9    P73_HUMAN.H11MO.0.A|-       P63_HUMAN.H11MO.0.A|+   SUH_HUMAN.H11MO.0.A|+

# %%
atf2_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.045371                     0.154215
# Precision           0.010298                     0.123425
# Recall              0.639896                     0.526944
# Accuracy            0.707807                     0.594089
# F1_score            0.020253                     0.199788
# ROCAUC              0.779731                     0.633072
#
#            induced_vs_repressed
# APS                    0.708835
# Precision              0.634789
# Recall                 0.714060
# Accuracy               0.727434
# F1_score               0.671833
# ROCAUC                 0.803681

# %% [markdown]
# # CTCF

# %%
ctcf_features_df, ctcf_scores_df = create_ko_specific_df(store_dir, ko_lines[1], categories)

# %%
ctcf_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive  \
# 0    P53_HUMAN.H11MO.0.A|+      ATF4_HUMAN.H11MO.0.A|+
# 1    P53_HUMAN.H11MO.0.A|-     CEBPG_HUMAN.H11MO.0.B|-
# 2    P63_HUMAN.H11MO.0.A|+      ATF4_HUMAN.H11MO.0.A|-
# 3    P63_HUMAN.H11MO.0.A|-     CEBPG_HUMAN.H11MO.0.B|+
# 4   ATF4_HUMAN.H11MO.0.A|+      ATF2_HUMAN.H11MO.0.B|+
# 5    P73_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|-
# 6    P73_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|+
# 7   ATF4_HUMAN.H11MO.0.A|-       P63_HUMAN.H11MO.0.A|+
# 8  CEBPG_HUMAN.H11MO.0.B|-       P63_HUMAN.H11MO.0.A|-
# 9   TYY1_HUMAN.H11MO.0.A|+      ATF3_HUMAN.H11MO.0.A|-
#
#       induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|+
# 1   ATF4_HUMAN.H11MO.0.A|+
# 2    P53_HUMAN.H11MO.0.A|-
# 3   ATF2_HUMAN.H11MO.0.B|+
# 4  CEBPG_HUMAN.H11MO.0.B|-
# 5   ATF4_HUMAN.H11MO.0.A|-
# 6    P73_HUMAN.H11MO.0.A|-
# 7    P73_HUMAN.H11MO.0.A|+
# 8    P63_HUMAN.H11MO.0.A|-
# 9    P63_HUMAN.H11MO.0.A|+

# %%
ctcf_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.058259                     0.154977
# Precision           0.025347                     0.103001
# Recall              0.546461                     0.597864
# Accuracy            0.688942                     0.679895
# F1_score            0.048439                     0.174724
# ROCAUC              0.756005                     0.743409
#
#            induced_vs_repressed
# APS                    0.936802
# Precision              0.867614
# Recall                 0.830514
# Accuracy               0.848253
# F1_score               0.847536
# ROCAUC                 0.923748

# %% [markdown]
# # FOXA1

# %%
foxa1_features_df, foxa1_scores_df = create_ko_specific_df(store_dir, ko_lines[2], categories)

# %%
foxa1_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive  \
# 0    P53_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|+
# 1    P53_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|-
# 2    P63_HUMAN.H11MO.0.A|+     FOSL1_HUMAN.H11MO.0.A|+
# 3    P63_HUMAN.H11MO.0.A|-     FOSL2_HUMAN.H11MO.0.A|-
# 4   ATF4_HUMAN.H11MO.0.A|+      MBD2_HUMAN.H11MO.0.B|+
# 5   ATF4_HUMAN.H11MO.0.A|-      ATF3_HUMAN.H11MO.0.A|-
# 6    P73_HUMAN.H11MO.0.A|+     MECP2_HUMAN.H11MO.0.C|-
# 7  CEBPG_HUMAN.H11MO.0.B|-     KAISO_HUMAN.H11MO.0.A|+
# 8  CREB1_HUMAN.H11MO.0.A|-     CREB1_HUMAN.H11MO.0.A|-
# 9    P73_HUMAN.H11MO.0.A|-       ZFX_HUMAN.H11MO.0.A|-
#
#       induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|-
# 1   CREM_HUMAN.H11MO.0.C|+
# 2    P53_HUMAN.H11MO.0.A|+
# 3   TYY1_HUMAN.H11MO.0.A|-
# 4    P63_HUMAN.H11MO.0.A|+
# 5  ZFP42_HUMAN.H11MO.0.A|+
# 6    SUH_HUMAN.H11MO.0.A|-
# 7    P63_HUMAN.H11MO.0.A|-
# 8  CREB1_HUMAN.H11MO.0.A|-
# 9  ZFP42_HUMAN.H11MO.0.A|-

# %%
foxa1_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.059363                     0.374243
# Precision           0.031999                     0.269844
# Recall              0.566147                     0.588537
# Accuracy            0.681020                     0.664412
# F1_score            0.060558                     0.366838
# ROCAUC              0.738903                     0.717628
#
#            induced_vs_repressed
# APS                    0.980916
# Precision              0.954224
# Recall                 0.840219
# Accuracy               0.805793
# F1_score               0.892366
# ROCAUC                 0.899497

# %% [markdown]
# # LEF1

# %%
lef1_features_df, lef1_scores_df = create_ko_specific_df(store_dir, ko_lines[3], categories)

# %%
lef1_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive  \
# 0    ZFX_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|+
# 1   ATF4_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|-
# 2   ATF4_HUMAN.H11MO.0.A|-       P63_HUMAN.H11MO.0.A|-
# 3   TYY1_HUMAN.H11MO.0.A|-     FOSL2_HUMAN.H11MO.0.A|-
# 4  CREB1_HUMAN.H11MO.0.A|-      ATF4_HUMAN.H11MO.0.A|+
# 5   TYY1_HUMAN.H11MO.0.A|+      JUND_HUMAN.H11MO.0.A|+
# 6    ZFX_HUMAN.H11MO.0.A|+      ERR3_HUMAN.H11MO.0.B|-
# 7  FOSL2_HUMAN.H11MO.0.A|-     STAT1_HUMAN.H11MO.0.A|+
# 8    SRY_HUMAN.H11MO.0.B|+      AP2C_HUMAN.H11MO.0.A|+
# 9  ARI5B_HUMAN.H11MO.0.C|+      ARNT_HUMAN.H11MO.0.B|+
#
#       induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|-
# 1    P53_HUMAN.H11MO.0.A|+
# 2    P73_HUMAN.H11MO.0.A|-
# 3    P63_HUMAN.H11MO.0.A|-
# 4    P63_HUMAN.H11MO.0.A|+
# 5    P73_HUMAN.H11MO.0.A|+
# 6  ZBT14_HUMAN.H11MO.0.C|-
# 7  FOSL1_HUMAN.H11MO.0.A|+
# 8  FOSL2_HUMAN.H11MO.0.A|+
# 9   ATF2_HUMAN.H11MO.0.B|-

# %%
lef1_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.040470                     0.155028
# Precision           0.023561                     0.078579
# Recall              0.520179                     0.519862
# Accuracy            0.664416                     0.632797
# F1_score            0.045067                     0.136409
# ROCAUC              0.732671                     0.673067
#
#            induced_vs_repressed
# APS                    0.760753
# Precision              0.646093
# Recall                 0.745342
# Accuracy               0.770725
# F1_score               0.690784
# ROCAUC                 0.855581

# %% [markdown]
# # SCRT1

# %%
scrt1_features_df, scrt1_scores_df = create_ko_specific_df(store_dir, ko_lines[4], categories)

# %%
scrt1_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive  \
# 0    P53_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|+
# 1    P53_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|-
# 2    P63_HUMAN.H11MO.0.A|+       P63_HUMAN.H11MO.0.A|-
# 3    P63_HUMAN.H11MO.0.A|-       P63_HUMAN.H11MO.0.A|+
# 4   ATF4_HUMAN.H11MO.0.A|+       P73_HUMAN.H11MO.0.A|+
# 5    P73_HUMAN.H11MO.0.A|+       P73_HUMAN.H11MO.0.A|-
# 6    P73_HUMAN.H11MO.0.A|-     CEBPD_HUMAN.H11MO.0.C|-
# 7   ATF4_HUMAN.H11MO.0.A|-     ZN449_HUMAN.H11MO.0.C|+
# 8  CEBPG_HUMAN.H11MO.0.B|-     ZBTB6_HUMAN.H11MO.0.C|+
# 9  CEBPG_HUMAN.H11MO.0.B|+     ZN528_HUMAN.H11MO.0.C|+
#
#       induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|+
# 1    P53_HUMAN.H11MO.0.A|-
# 2   ATF4_HUMAN.H11MO.0.A|-
# 3    P63_HUMAN.H11MO.0.A|+
# 4    P73_HUMAN.H11MO.0.A|-
# 5    P73_HUMAN.H11MO.0.A|+
# 6    P63_HUMAN.H11MO.0.A|-
# 7  CEBPG_HUMAN.H11MO.0.B|+
# 8   E2F5_HUMAN.H11MO.0.B|-
# 9   ATF4_HUMAN.H11MO.0.A|+

# %%
scrt1_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.071207                     0.191692
# Precision           0.028874                     0.064055
# Recall              0.568831                     0.592113
# Accuracy            0.698012                     0.721455
# F1_score            0.054943                     0.115453
# ROCAUC              0.768553                     0.776798
#
#            induced_vs_repressed
# APS                    0.981112
# Precision              0.952255
# Recall                 0.956468
# Accuracy               0.617787
# F1_score               0.954287
# ROCAUC                 0.789935

# %% [markdown]
# # TCF7L2

# %%
tcf7l2_features_df, tcf7l2_scores_df = create_ko_specific_df(store_dir, ko_lines[5], categories)

# %%
tcf7l2_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive  \
# 0    P53_HUMAN.H11MO.0.A|+      ATF4_HUMAN.H11MO.0.A|-
# 1   ATF4_HUMAN.H11MO.0.A|+      ATF4_HUMAN.H11MO.0.A|+
# 2    P53_HUMAN.H11MO.0.A|-       P53_HUMAN.H11MO.0.A|-
# 3   ATF4_HUMAN.H11MO.0.A|-     CREB1_HUMAN.H11MO.0.A|+
# 4    ZFX_HUMAN.H11MO.0.A|-     CEBPG_HUMAN.H11MO.0.B|-
# 5   TYY1_HUMAN.H11MO.0.A|-     CEBPG_HUMAN.H11MO.0.B|+
# 6  CREB1_HUMAN.H11MO.0.A|-      ATF2_HUMAN.H11MO.0.B|-
# 7   TYY1_HUMAN.H11MO.0.A|+     CREB1_HUMAN.H11MO.0.A|-
# 8  ZFP42_HUMAN.H11MO.0.A|-       P63_HUMAN.H11MO.0.A|-
# 9    P63_HUMAN.H11MO.0.A|+      ATF1_HUMAN.H11MO.0.B|+
#
#       induced_vs_repressed
# 0    ZFX_HUMAN.H11MO.0.A|+
# 1  SNAI2_HUMAN.H11MO.0.A|+
# 2   MYCN_HUMAN.H11MO.0.A|+
# 3  SNAI2_HUMAN.H11MO.0.A|-
# 4   ZIC3_HUMAN.H11MO.0.B|+
# 5  BHE40_HUMAN.H11MO.0.A|+
# 6   KLF8_HUMAN.H11MO.0.C|-
# 7  ZN768_HUMAN.H11MO.0.C|+
# 8    REL_HUMAN.H11MO.0.B|+
# 9   ATF4_HUMAN.H11MO.0.A|+

# %%
tcf7l2_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.052164                     0.073462
# Precision           0.029923                     0.062629
# Recall              0.558496                     0.500160
# Accuracy            0.673213                     0.606432
# F1_score            0.056787                     0.111244
# ROCAUC              0.733372                     0.644628
#
#            induced_vs_repressed
# APS                    0.990097
# Precision              0.977569
# Recall                 0.875385
# Accuracy               0.661119
# F1_score               0.923264
# ROCAUC                 0.790658

# %% [markdown]
# # 16p12.1

# %%
cnv_features_df, cnv_scores_df= create_ko_specific_df(store_dir, ko_lines[6], categories)

# %%
cnv_features_df
# Out:
#          peaks_vs_notpeaks responsive_vs_nonresponsive    induced_vs_repressed
# 0    P53_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|+   ZFX_HUMAN.H11MO.0.A|-
# 1    P53_HUMAN.H11MO.0.A|-       ZFX_HUMAN.H11MO.0.A|+   ZFX_HUMAN.H11MO.0.A|+
# 2   ATF4_HUMAN.H11MO.0.A|+       P53_HUMAN.H11MO.0.A|-   P53_HUMAN.H11MO.0.A|-
# 3   ATF4_HUMAN.H11MO.0.A|-       ZFX_HUMAN.H11MO.0.A|-   P53_HUMAN.H11MO.0.A|+
# 4   TYY1_HUMAN.H11MO.0.A|+       P63_HUMAN.H11MO.0.A|-   P73_HUMAN.H11MO.0.A|+
# 5   TYY1_HUMAN.H11MO.0.A|-     ZN335_HUMAN.H11MO.0.A|+   P73_HUMAN.H11MO.0.A|-
# 6  CREB1_HUMAN.H11MO.0.A|-      LHX3_HUMAN.H11MO.0.C|-  MYCN_HUMAN.H11MO.0.A|+
# 7    P63_HUMAN.H11MO.0.A|-      ELF5_HUMAN.H11MO.0.A|+   P63_HUMAN.H11MO.0.A|-
# 8    P63_HUMAN.H11MO.0.A|+     TF7L1_HUMAN.H11MO.0.B|+   P63_HUMAN.H11MO.0.A|+
# 9   ELK4_HUMAN.H11MO.0.A|-       SP1_HUMAN.H11MO.0.A|-  E2F5_HUMAN.H11MO.0.B|-

# %%
cnv_scores_df
# Out:
#            peaks_vs_notpeaks  responsive_vs_nonresponsive  \
# APS                 0.069576                     0.089286
# Precision           0.030844                     0.060217
# Recall              0.566829                     0.570169
# Accuracy            0.690346                     0.687484
# F1_score            0.058491                     0.108627
# ROCAUC              0.759160                     0.752576
#
#            induced_vs_repressed
# APS                    0.858173
# Precision              0.785539
# Recall                 0.795309
# Accuracy               0.828563
# F1_score               0.788642
# ROCAUC                 0.908111
