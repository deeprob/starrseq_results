# %%
import pandas as pd

# %%
df = pd.read_csv("/data7/deepro/starrseq/4_ml_classification_fragment_category/data/16P12_1/linear/homer/motif_odds.tsv", sep="\t")

# %%
df.loc[df.PositionID=="chr17_20908289_20909289"].sort_values("MotifScore", ascending=False).head(50)
# Out:
#                        PositionID  Offset                Sequence  \
# 48814933  chr17_20908289_20909289     312    CACTGGCCCCTGAGCCCCAG
# 28090030  chr17_20908289_20909289     396       CACGCGCAGGCGCGCTG
# 4487400   chr17_20908289_20909289     189       GCCACGAGGCGGCGCAG
# 5135708   chr17_20908289_20909289     343          GGGTGGCGGGAAGA
# 41365802  chr17_20908289_20909289     343          GGGTGGCGGGAAGA
# 14857645  chr17_20908289_20909289     652             ATTATTGATTT
# 6280486   chr17_20908289_20909289     345           GTGGCGGGAAGAG
# 11676781  chr17_20908289_20909289     128           AAAATAAAAACAT
# 28959947  chr17_20908289_20909289     717     ATGCATGTCCCAACTAGTT
# 28386179  chr17_20908289_20909289     529        CCTCCTGCTGCTGCTC
# 28861552  chr17_20908289_20909289     718     TGCATGTCCCAACTAGTTC
# 49604501  chr17_20908289_20909289     337  TAGCCCGGGTGGCGGGAAGAGC
# 48991811  chr17_20908289_20909289     474    GAGCCCAGGCCACTGCCAGG
# ...

# %%
df
# Out:
#                         PositionID  Offset            Sequence  \
# 0         chrX_154800144_154801144      24           TTTGCATGG
# 1         chrX_154800144_154801144     331           ACATGCAAA
# 2         chrX_154800144_154801144      14           GCTCGCAAA
# 3         chrX_154800044_154801044     124           TTTGCATGG
# 4         chrX_154800044_154801044     431           ACATGCAAA
# ...                            ...     ...                 ...
# 54192173        chr1_910305_911305     944  GGCAGCACGGCGATCACC
# 54192174        chr1_910305_911305     832  CCTCCCCGCCCCACTGTG
# 54192175        chr1_910305_911305     544  GAGGCCGGCACTGCTGAA
# 54192176        chr1_910305_911305     459  AAACCCAGCCCTGCCGCT
# 54192177        chr1_910305_911305     387  CGTGCCCGCCAGGCTGCC
#
#                      Motif Name Strand  MotifScore
# 0           AHR_HUMAN.H11MO.0.B      +    3.842687
# 1           AHR_HUMAN.H11MO.0.B      -    4.355972
# 2           AHR_HUMAN.H11MO.0.B      -    3.886547
# ...
