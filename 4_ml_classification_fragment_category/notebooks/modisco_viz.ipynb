# %%
import pandas as pd

# %%
df = pd.read_csv("/data7/deepro/starrseq/4_ml_classification_fragment_category/data/FOXA1/linear/homer/motif_features.csv.gz")

# %%
mydict = {"hs": ""}

if "hs" in mydict and mydict["hs"]:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
import pandas as pd

# %%
df = pd.read_hdf("/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/resnet_1000.h5")

# %%
df.split.value_counts(normalize=True)
# Out:
# split
# train    0.699857
# test     0.150279
# valid    0.149864
# Name: proportion, dtype: float64

# %%
df.loc[df.label==0]
# Out:
#        chrm      start        end  label  split
# 4308   chr1     910305     911305      0  train
# 4309   chr1     910405     911405      0   test
# 4310   chr1     910505     911505      0  train
# 4311   chr1     910605     911605      0  train
# 4312   chr1     910705     911705      0  train
# ...     ...        ...        ...    ...    ...
# 51187  chrX  154370059  154371059      0  valid
# 51188  chrX  154370159  154371159      0  train
# 51189  chrX  154370259  154371259      0  train
# 51192  chrX  154800044  154801044      0  train
# 51193  chrX  154800144  154801144      0  train
#
# [39138 rows x 5 columns]

# %%
from IPython.display import HTML
HTML('/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/motifs.html')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pattern</th>
#       <th>num_seqlets</th>
#       <th>modisco_cwm_fwd</th>
#       <th>modisco_cwm_rev</th>
#       <th>match0</th>
#       <th>qval0</th>
#       <th>match0_logo</th>
#       <th>match1</th>
#       <th>qval1</th>
#       <th>match1_logo</th>
#       <th>match2</th>
#       <th>qval2</th>
#       <th>match2_logo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>pos_patterns.pattern_0</td>
#       <td>96</td>
#       <td><img src="/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.fwd.png" width="240" ></td>
#       <td><img src="/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.rev.png" width="240" ></td>
#       <td>PBX3_HUMAN.H11MO.0.A</td>
#       <td>1.000000e+00</td>
# ...

# %%
from IPython.display import HTML
HTML('/data7/deepro/pipelines/biopeaker/data/tmp/resnet_1000/modisco_results/motifs.html')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pattern</th>
#       <th>num_seqlets</th>
#       <th>modisco_cwm_fwd</th>
#       <th>modisco_cwm_rev</th>
#       <th>match0</th>
#       <th>qval0</th>
#       <th>match0_logo</th>
#       <th>match1</th>
#       <th>qval1</th>
#       <th>match1_logo</th>
#       <th>match2</th>
#       <th>qval2</th>
#       <th>match2_logo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>pos_patterns.pattern_0</td>
#       <td>97</td>
#       <td><img src="/data7/deepro/pipelines/biopeaker/data/tmp/resnet_1000/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.fwd.png" width="240" ></td>
#       <td><img src="/data7/deepro/pipelines/biopeaker/data/tmp/resnet_1000/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.rev.png" width="240" ></td>
#       <td>CTCFL_HUMAN.H11MO.0.A</td>
#       <td>5.428180e-05</td>
# ...

# %%
from IPython.display import HTML
HTML('/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/motifs.html')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pattern</th>
#       <th>num_seqlets</th>
#       <th>modisco_cwm_fwd</th>
#       <th>modisco_cwm_rev</th>
#       <th>match0</th>
#       <th>qval0</th>
#       <th>match0_logo</th>
#       <th>match1</th>
#       <th>qval1</th>
#       <th>match1_logo</th>
#       <th>match2</th>
#       <th>qval2</th>
#       <th>match2_logo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>pos_patterns.pattern_0</td>
#       <td>96</td>
#       <td><img src="/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.fwd.png" width="240" ></td>
#       <td><img src="/data7/deepro/starrseq/4_ml_classification_fragment_category/data/CC/modisco_results/trimmed_logos/pos_patterns.pattern_0.cwm.rev.png" width="240" ></td>
#       <td>PBX3_HUMAN.H11MO.0.A</td>
#       <td>1.000000e+00</td>
# ...
