# %%
import os
import pandas as pd

# %%
results_dir = "../data/"
libs = ["CC", "ATF2", "CTCF", "FOXA1", "LEF1", "SCRT1", "TCF7L2", "16P12_1"]
c_types = ["peaks_vs_notpeaks", "responsive_vs_nonresponsive", "induced_vs_repressed"]
methods = ["homer", "meme"]

# %%
def get_homer_results(resdir, lib, ct):
    filename = os.path.join(resdir, lib, "homer", ct, "knownResults.txt")
    df = pd.read_csv(filename, sep="\t")
    df["Motif Name"] = df["Motif Name"].str.split("/", expand=True)[0]
    df = df.loc[df["q-value (Benjamini)"]<0.01]
    return df

def get_meme_results(resdir, lib, ct):
    filename = os.path.join(resdir, lib, "meme", ct, "ame.tsv")
    df = pd.read_csv(filename, sep="\t")
    df["motif_ID"] = df["motif_ID"].str.split(".", expand=True)[0]
    df = df.loc[df["adj_p-value"]<0.01]
    return df

def get_top_motifs(resdir, libs, ct, method, N=30):
    method_func_dict = {"homer": get_homer_results, "meme": get_meme_results}
    method_colname_dict = {"homer": "Motif Name", "meme": "motif_ID"}
    dfs = [method_func_dict[method](resdir, lib, ct).iloc[:N] for lib in libs]
    dfs = [df[method_colname_dict[method]] for df in dfs]
    df = pd.concat(dfs, axis=1)
    df.columns = libs
    return df

# %%
get_top_motifs(results_dir, libs[1:], c_types[1], "meme", N=30)
# Out:
#            ATF2         CTCF        FOXA1         LEF1        SCRT1  \
# 0     P53_HUMAN  THAP1_HUMAN  THAP1_HUMAN    P53_HUMAN    P53_HUMAN
# 1     P63_HUMAN    SP2_HUMAN    SP2_HUMAN    P73_HUMAN    P63_HUMAN
# 2     P73_HUMAN    SP3_HUMAN    SP3_HUMAN    P63_HUMAN    P73_HUMAN
# 3    ATF4_HUMAN   AP2B_HUMAN   KLF3_HUMAN  CEBPG_HUMAN  ZN449_HUMAN
# 4   CEBPG_HUMAN   KLF3_HUMAN   E2F4_HUMAN   ATF4_HUMAN  SMAD3_HUMAN
# 5    ZIC1_HUMAN   E2F4_HUMAN   AP2B_HUMAN  FOSL1_HUMAN  SRBP1_HUMAN
# 6     FEV_HUMAN   KLF6_HUMAN  MECP2_HUMAN  FOSL2_HUMAN  THAP1_HUMAN
# 7   SMAD3_HUMAN  KLF12_HUMAN    SP1_HUMAN   JUND_HUMAN   E2F3_HUMAN
# 8    KLF6_HUMAN    SP1_HUMAN   KLF6_HUMAN    JUN_HUMAN    SP3_HUMAN
# 9     SUH_HUMAN  MECP2_HUMAN  KLF12_HUMAN   JUNB_HUMAN  SALL4_HUMAN
# 10  SRBP2_HUMAN   KLF1_HUMAN   KLF1_HUMAN  THAP1_HUMAN   KLF6_HUMAN
# 11   LYL1_HUMAN   ZIC1_HUMAN   ZIC1_HUMAN   FOSB_HUMAN  BACH1_HUMAN
# 12  SALL4_HUMAN  PATZ1_HUMAN  PATZ1_HUMAN    FOS_HUMAN  GRHL2_HUMAN
# 13  TBX21_HUMAN   KLF5_HUMAN    SP4_HUMAN    SP3_HUMAN  TEAD1_HUMAN
# 14   EGR1_HUMAN   E2F1_HUMAN    FEV_HUMAN  BACH1_HUMAN    THA_HUMAN
# 15   EGR2_HUMAN  CEBPG_HUMAN   EGR1_HUMAN   AP2B_HUMAN  PATZ1_HUMAN
# 16  PATZ1_HUMAN   EGR1_HUMAN   E2F1_HUMAN   KLF6_HUMAN  NR1D1_HUMAN
# 17    SP3_HUMAN  SALL4_HUMAN    WT1_HUMAN    SP2_HUMAN   ZIC1_HUMAN
# 18   ITF2_HUMAN  SRBP2_HUMAN   KLF5_HUMAN  SALL4_HUMAN  ZBT17_HUMAN
# 19  ZBT17_HUMAN   ATF4_HUMAN   MBD2_HUMAN   KLF5_HUMAN    ZFX_HUMAN
# 20    SP4_HUMAN    WT1_HUMAN  SRBP2_HUMAN   E2F3_HUMAN   EGR1_HUMAN
# 21  IKZF1_HUMAN    SP4_HUMAN  NR1H4_HUMAN  Z324A_HUMAN    SP4_HUMAN
# 22   KLF5_HUMAN  CTCFL_HUMAN   E2F7_HUMAN   ZIC1_HUMAN  ZN768_HUMAN
# 23  ZN341_HUMAN  TFDP1_HUMAN  TFDP1_HUMAN   MXI1_HUMAN   MXI1_HUMAN
# 24   TBX3_HUMAN  ZBT7A_HUMAN  SALL4_HUMAN    ZFX_HUMAN   ITF2_HUMAN
# 25  SRBP1_HUMAN   KLF4_HUMAN  KLF15_HUMAN  ZN554_HUMAN  CLOCK_HUMAN
# 26   KLF3_HUMAN    FEV_HUMAN    ZFX_HUMAN    FEV_HUMAN   AP2C_HUMAN
# 27   RXRA_HUMAN   E2F7_HUMAN  ZBT7A_HUMAN   NFE2_HUMAN   LYL1_HUMAN
# 28  VEZF1_HUMAN  KLF15_HUMAN  ZN281_HUMAN  ZN449_HUMAN  SRBP2_HUMAN
# 29    MAZ_HUMAN  NR1H4_HUMAN   EGR2_HUMAN   KLF3_HUMAN  Z324A_HUMAN
#
#          TCF7L2      16P12_1
# 0   CEBPG_HUMAN    ZFX_HUMAN
# 1    ATF4_HUMAN    P53_HUMAN
# 2     P53_HUMAN    P73_HUMAN
# 3     P63_HUMAN    P63_HUMAN
# 4     JUN_HUMAN   AP2B_HUMAN
# 5    JUND_HUMAN    SP2_HUMAN
# 6     P73_HUMAN  THAP1_HUMAN
# 7   FOSL2_HUMAN    SP3_HUMAN
# 8   FOSL1_HUMAN   ZIC1_HUMAN
# 9    FOSB_HUMAN  SRBP2_HUMAN
# 10   JUNB_HUMAN   KLF6_HUMAN
# 11    FOS_HUMAN  NR1H4_HUMAN
# 12   ATF2_HUMAN   AP2C_HUMAN
# 13  CREB1_HUMAN  MECP2_HUMAN
# 14   ATF1_HUMAN   KLF3_HUMAN
# 15   NFE2_HUMAN   ITF2_HUMAN
# 16  BACH1_HUMAN  PATZ1_HUMAN
# 17  THAP1_HUMAN  SALL4_HUMAN
# 18    FEV_HUMAN  ZN563_HUMAN
# 19   CREM_HUMAN    SP4_HUMAN
# 20   TYY1_HUMAN  SMAD3_HUMAN
# 21   E2F4_HUMAN   AP2A_HUMAN
# 22    ZFX_HUMAN   KLF5_HUMAN
# 23  BACH2_HUMAN  ZN341_HUMAN
# 24  PATZ1_HUMAN    FEV_HUMAN
# 25    SP3_HUMAN   EGR1_HUMAN
# 26   AP2B_HUMAN   MXI1_HUMAN
# 27    SP2_HUMAN    WT1_HUMAN
# 28   ATF3_HUMAN  KLF15_HUMAN
# 29  NF2L2_HUMAN   NFIC_HUMAN
