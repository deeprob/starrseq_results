# %%
import os
import pandas as pd

# %%
results_dir = "../data/"
libs = ["CC", "ATF2", "CTCF", "FOXA1", "LEF1", "SCRT1", "TCF7L2", "16P12_1"]
c_types = ["peaks_vs_notpeaks", "responsive_vs_nonresponsive", "induced_vs_repressed"]
methods = ["homer", "meme"]

# %%
def get_homer_results(resdir, lib, ct):
    filename = os.path.join(resdir, lib, "homer", ct, "knownResults.txt")
    df = pd.read_csv(filename, sep="\t")
    df["Motif Name"] = df["Motif Name"].str.split("/", expand=True)[0]
    df = df.loc[df["q-value (Benjamini)"]<0.01]
    return df

def get_meme_results(resdir, lib, ct):
    filename = os.path.join(resdir, lib, "meme", ct, "ame.tsv")
    df = pd.read_csv(filename, sep="\t")
    df["motif_ID"] = df["motif_ID"].str.split(".", expand=True)[0]
    df = df.loc[df["adj_p-value"]<0.01]
    return df

def get_top_motifs(resdir, libs, ct, method, N=30):
    method_func_dict = {"homer": get_homer_results, "meme": get_meme_results}
    method_colname_dict = {"homer": "Motif Name", "meme": "motif_ID"}
    dfs = [method_func_dict[method](resdir, lib, ct).iloc[:N] for lib in libs]
    dfs = [df[method_colname_dict[method]] for df in dfs]
    df = pd.concat(dfs, axis=1)
    df.columns = libs
    return df

# %%
get_top_motifs(results_dir, libs[1:], c_types[2], "meme", N=30)
# Out:
#            ATF2         CTCF        FOXA1         LEF1        SCRT1  \
# 0    TBX3_HUMAN    SP2_HUMAN    SP3_HUMAN  FOSL2_HUMAN    P53_HUMAN
# 1   TBX21_HUMAN    SP3_HUMAN    SP2_HUMAN    FOS_HUMAN    P73_HUMAN
# 2     SUH_HUMAN   ZIC1_HUMAN   KLF6_HUMAN   JUNB_HUMAN    P63_HUMAN
# 3    KLF5_HUMAN   AP2B_HUMAN   AP2B_HUMAN   FOSB_HUMAN  ZBT48_HUMAN
# 4    KLF1_HUMAN   KLF3_HUMAN   KLF3_HUMAN    JUN_HUMAN    ZFX_HUMAN
# 5   SALL4_HUMAN   KLF6_HUMAN  SALL4_HUMAN   JUND_HUMAN  ZSC31_HUMAN
# 6    EGR2_HUMAN  SALL4_HUMAN   ZIC1_HUMAN  FOSL1_HUMAN  ZN667_HUMAN
# 7    KLF9_HUMAN   KLF1_HUMAN  SRBP2_HUMAN   E2F4_HUMAN   COT1_HUMAN
# 8    KLF6_HUMAN  KLF12_HUMAN   KLF5_HUMAN  NF2L1_HUMAN   PAX6_HUMAN
# 9    ITF2_HUMAN   KLF5_HUMAN    SP4_HUMAN  ZBT14_HUMAN   E2F4_HUMAN
# 10   EGR1_HUMAN  ZBT7A_HUMAN   KLF1_HUMAN    SP3_HUMAN  BC11A_HUMAN
# 11   KLF4_HUMAN   EGR1_HUMAN  PATZ1_HUMAN    SP2_HUMAN   ZEB1_HUMAN
# 12  SRBP2_HUMAN   E2F4_HUMAN   EGR1_HUMAN    SP1_HUMAN    SUH_HUMAN
# 13   ZIC1_HUMAN  PATZ1_HUMAN  THAP1_HUMAN   MBD2_HUMAN  SMAD2_HUMAN
# 14   KLF3_HUMAN  THAP1_HUMAN  KLF12_HUMAN   ATF2_HUMAN  GRHL2_HUMAN
# 15  ZBT17_HUMAN    SP4_HUMAN   E2F4_HUMAN   E2F2_HUMAN   RXRB_HUMAN
# 16  SMAD3_HUMAN  MECP2_HUMAN   EGR2_HUMAN  THAP1_HUMAN  BHE40_HUMAN
# 17    SP4_HUMAN   KLF4_HUMAN    WT1_HUMAN  KAISO_HUMAN    MYC_HUMAN
# 18  IKZF1_HUMAN    SP1_HUMAN    ZFX_HUMAN   E2F1_HUMAN  ZNF76_HUMAN
# 19  KLF12_HUMAN  KLF15_HUMAN   E2F7_HUMAN   E2F7_HUMAN  Z324A_HUMAN
# 20   HTF4_HUMAN    WT1_HUMAN  ZBT7A_HUMAN  MECP2_HUMAN  PRDM1_HUMAN
# 21  KLF15_HUMAN   EGR2_HUMAN  ZN770_HUMAN   KLF3_HUMAN  GABPA_HUMAN
# 22    SP3_HUMAN  ZN281_HUMAN   E2F1_HUMAN  TFDP1_HUMAN    SP4_HUMAN
# 23  PATZ1_HUMAN  SRBP2_HUMAN  MECP2_HUMAN   HXA9_HUMAN  CLOCK_HUMAN
# 24   MXI1_HUMAN   KLF9_HUMAN    MAZ_HUMAN  KLF12_HUMAN   PEBB_HUMAN
# 25    MAZ_HUMAN   E2F1_HUMAN  KLF15_HUMAN   KLF9_HUMAN  ZN341_HUMAN
# 26  VEZF1_HUMAN   MBD2_HUMAN  TFDP1_HUMAN  NKX61_HUMAN   MXI1_HUMAN
# 27  SNAI1_HUMAN    MAZ_HUMAN   AP2C_HUMAN   NRF1_HUMAN   RFX5_HUMAN
# 28    SP2_HUMAN  CTCFL_HUMAN   E2F6_HUMAN   CDX1_HUMAN   TAF1_HUMAN
# 29   RXRA_HUMAN   E2F7_HUMAN  ZN341_HUMAN   ELK4_HUMAN   RORA_HUMAN
#
#          TCF7L2      16P12_1
# 0   CEBPG_HUMAN    P53_HUMAN
# 1    ATF4_HUMAN    P73_HUMAN
# 2     JUN_HUMAN    P63_HUMAN
# 3   NF2L1_HUMAN   CDX1_HUMAN
# 4    BATF_HUMAN    SRY_HUMAN
# 5   FOSL1_HUMAN   HXA9_HUMAN
# 6    JUND_HUMAN  PRDM6_HUMAN
# 7   FOSL2_HUMAN  HXB13_HUMAN
# 8     SRY_HUMAN   PIT1_HUMAN
# 9    CDX1_HUMAN   ANDR_HUMAN
# 10   JUNB_HUMAN    TBP_HUMAN
# 11  ZN394_HUMAN  NKX61_HUMAN
# 12  HXB13_HUMAN  FOXK1_HUMAN
# 13    FOS_HUMAN  MEIS1_HUMAN
# 14   FOSB_HUMAN  FOXP1_HUMAN
# 15    DBP_HUMAN  NF2L1_HUMAN
# 16  NF2L2_HUMAN   HXC9_HUMAN
# 17   MYCN_HUMAN   FOSB_HUMAN
# 18   PIT1_HUMAN  GATA3_HUMAN
# 19  NKX61_HUMAN  HXA10_HUMAN
# 20  CEBPE_HUMAN  PO2F1_HUMAN
# 21  BACH2_HUMAN  PO2F2_HUMAN
# 22   NFE2_HUMAN  NKX32_HUMAN
# 23   MAFK_HUMAN   CDX2_HUMAN
# 24  MEF2A_HUMAN   IRF7_HUMAN
# 25  MEF2D_HUMAN   HXB4_HUMAN
# 26    TBP_HUMAN  ZN394_HUMAN
# 27  CEBPB_HUMAN  FOXJ2_HUMAN
# 28    HLF_HUMAN    FOS_HUMAN
# 29   HXA9_HUMAN  MEF2A_HUMAN
