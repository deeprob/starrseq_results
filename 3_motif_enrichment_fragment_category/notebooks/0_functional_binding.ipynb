# %% [markdown]
# # Motifs that were enriched in functional binding sites

# %%
import pandas as pd

# %% [markdown]
# # Homer motifs

# %%
homer_file = "/data5/deepro/starrseq/papers/results/2_motif_enrichment_fragment_category/data/CC/homer/peaks_vs_notpeaks/knownResults.txt"

homer_df = pd.read_csv(homer_file, sep="\t")

homer_df.head(10)
# Out:
#                                           Motif Name             Consensus  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer  NRRRCAWGTCCDGRCATGYY
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer  RRCATGYCYRGRCATGYYYN
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer  RRCATGYCYRGRCATGYYYN
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...  NNDRCATGYCYNRRCATGYH
# 4       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer            ATTGCATCAT
# 5         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer        ACATGCCCGGGCAT
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer            GATTGCATCA
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer            MTGATGCAAT
# 8     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer       VTTACGTAAYNNNNN
# 9  CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512...            DRTGTTGCAA
#
#          P-value  Log P-value  q-value (Benjamini)  \
# 0   0.000000e+00      -1407.0                  0.0
# 1   0.000000e+00      -1252.0                  0.0
# 2   0.000000e+00      -1252.0                  0.0
# 3  1.000000e-276       -635.9                  0.0
# 4  1.000000e-228       -525.5                  0.0
# 5  1.000000e-206       -476.3                  0.0
# 6  1.000000e-205       -474.2                  0.0
# 7  1.000000e-204       -470.2                  0.0
# 8   1.000000e-82       -189.2                  0.0
# 9   1.000000e-69       -160.7                  0.0
#
#    # of Target Sequences with Motif(of 2376) % of Target Sequences with Motif  \
# 0                                      592.0                           24.92%
# 1                                      664.0                           27.95%
# 2                                      664.0                           27.95%
# 3                                      772.0                           32.49%
# 4                                      607.0                           25.55%
# 5                                      213.0                            8.96%
# 6                                      381.0                           16.04%
# 7                                      651.0                           27.40%
# 8                                      771.0                           32.45%
# 9                                      811.0                           34.13%
#
#    # of Background Sequences with Motif(of 238752)  \
# 0                                           2411.4
# 1                                           4587.0
# 2                                           4587.0
# 3                                          17692.7
# 4                                          12795.9
# 5                                            929.7
# 6                                           4962.4
# 7                                          16488.1
# 8                                          38870.6
# 9                                          44620.8
#
#   % of Background Sequences with Motif
# 0                                1.01%
# 1                                1.93%
# 2                                1.93%
# 3                                7.44%
# 4                                5.38%
# 5                                0.39%
# 6                                2.09%
# 7                                6.93%
# 8                               16.34%
# 9                               18.76%

# %% [markdown]
# # Meme motifs

# %%
meme_file = "/data5/deepro/starrseq/papers/results/2_motif_enrichment_fragment_category/data/CC/meme/peaks_vs_notpeaks/ame.tsv"

meme_df = pd.read_csv(meme_file, sep="\t")

meme_df.head(10)
# Out:
#   rank                                           motif_DB  \
# 0    1  /data5/deepro/starrseq/papers/results/2_motif_...
# 1    2  /data5/deepro/starrseq/papers/results/2_motif_...
# 2    3  /data5/deepro/starrseq/papers/results/2_motif_...
# 3    4  /data5/deepro/starrseq/papers/results/2_motif_...
# 4    5  /data5/deepro/starrseq/papers/results/2_motif_...
# 5    6  /data5/deepro/starrseq/papers/results/2_motif_...
# 6    7  /data5/deepro/starrseq/papers/results/2_motif_...
# 7    8  /data5/deepro/starrseq/papers/results/2_motif_...
# 8    9  /data5/deepro/starrseq/papers/results/2_motif_...
# 9   10  /data5/deepro/starrseq/papers/results/2_motif_...
#
#                 motif_ID  motif_alt_ID             consensus        p-value  \
# 0    P53_HUMAN.H11MO.0.A           NaN  DGRCATGYCCAGRCATGYCY   0.000000e+00
# 1    P63_HUMAN.H11MO.0.A           NaN   DRCAWGYCCAGRCWTGYYB   0.000000e+00
# 2    P73_HUMAN.H11MO.0.A           NaN   RRRCAWGYCCARRCWTGYC   0.000000e+00
# 3  CEBPG_HUMAN.H11MO.0.B           NaN          RTTGCATCAKHH  4.590000e-302
# 4   ATF4_HUMAN.H11MO.0.A           NaN          RRMTGATGCAAY  3.270000e-291
# 5   TYY1_HUMAN.H11MO.0.A           NaN          CAARATGGCGGC   6.730000e-95
# 6  CREB1_HUMAN.H11MO.0.A           NaN           NRRTGACGTMA   3.640000e-69
# 7   ATF2_HUMAN.H11MO.0.B           NaN           RRTGABGTCAY   7.220000e-67
# 8  CEBPD_HUMAN.H11MO.0.C           NaN           VTTGCRCMAYC   2.880000e-65
# 9  CEBPB_HUMAN.H11MO.0.A           NaN          DRTTRYGCAATM   2.420000e-64
#
#      adj_p-value        E-value    tests  FASTA_max     pos       neg  \
# 0   0.000000e+00   0.000000e+00  14047.0     2376.0  2376.0  251256.0
# 1   0.000000e+00   0.000000e+00  24023.0     2376.0  2376.0  251256.0
# 2   0.000000e+00   0.000000e+00  42369.0     2376.0  2376.0  251256.0
# 3  1.440000e-297  5.790000e-295  31445.0     2376.0  2376.0  251256.0
# 4  4.820000e-287  1.930000e-284  14743.0     2376.0  2376.0  251256.0
# 5   8.450000e-91   3.390000e-88  12555.0     2376.0  2376.0  251256.0
# 6   8.890000e-65   3.570000e-62  24399.0     2376.0  2376.0  251256.0
# 7   3.860000e-62   1.550000e-59  53457.0     2376.0  2376.0  251256.0
# 8   1.660000e-60   6.670000e-58  57794.0     2376.0  2376.0  251256.0
# 9   9.380000e-60   3.760000e-57  38731.0     2376.0  2376.0  251256.0
#
#    PWM_min     TP    %TP       FP    %FP
# 0    65.00  554.0  23.32   1576.0   0.63
# 1    70.20  509.0  21.42   1883.0   0.75
# 2    40.90  544.0  22.90   2523.0   1.00
# 3    23.90  384.0  16.16   2686.0   1.07
# 4    20.70  391.0  16.46   3056.0   1.22
# 5    24.30  133.0   5.60   1094.0   0.44
# 6     1.02  513.0  21.59  23714.0   9.44
# 7     1.02  864.0  36.36  52415.0  20.86
# 8     2.41  422.0  17.76  17948.0   7.14
# 9     5.00  304.0  12.79  10488.0   4.17
