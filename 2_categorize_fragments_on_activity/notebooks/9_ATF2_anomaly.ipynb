# %%
import os
import pandas as pd

# plotting modules
import matplotlib.colors as colors
import seaborn as sns
from matplotlib.ticker import MultipleLocator
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.sans-serif'] = "Arial" # missing fonts:: https://alexanderlabwhoi.github.io/post/2021-03-missingfont/
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
matplotlib.rcParams.update({'font.size': 14, 'axes.linewidth': 2, 'xtick.major.width': 1.5, 'xtick.major.size': 5, 'ytick.major.width': 1.5, 'ytick.major.size': 4})
from matplotlib.backends.backend_pdf import PdfPages
# Out:
# /data5/deepro/miniconda3/envs/starrseq/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def save_pdf(save_file, fig):
    pdf = PdfPages(save_file)
    pdf.savefig(fig, bbox_inches='tight', dpi=300)
    pdf.close()
    return

# %%
homer_result = "/data5/deepro/starrseq/papers/results/3_motif_enrichment_fragment_category/data/ATF2/homer/responsive_low_active/knownResults.txt"
homer_df = pd.read_csv(homer_result, sep="\t")

# %%
homer_df
# Out:
#                                             Motif Name        Consensus  \
# 0        Rbpj1(?)/Panc1-Rbpj1-ChIP-Seq(GSE47459)/Homer       HTTTCCCASG
# 1        KLF1(Zf)/HUDEP2-KLF1-CutnRun(GSE136251)/Homer     VDGGGYGGGGCY
# 2           Klf9(Zf)/GBM-Klf9-ChIP-Seq(GSE62211)/Homer     GCCACRCCCACY
# 3           KLF3(Zf)/MEF-Klf3-ChIP-Seq(GSE44748)/Homer  NRGCCCCRCCCHBNN
# 4           Klf4(Zf)/mES-Klf4-ChIP-Seq(GSE11431)/Homer       GCCACACCCA
# ...                                                ...              ...
# 1001   DEL1(E2FDP)/colamp-DEL1-DAP-Seq(GSE60143)/Homer       TTCCCGCCAA
# 1002       IDD4(C2H2)/col-IDD4-DAP-Seq(GSE60143)/Homer     TTTGTCTTTWTB
# 1003    IDD5(C2H2)/colamp-IDD5-DAP-Seq(GSE60143)/Homer  TTTTGTCTTTTTBTK
# 1004          NAM(NAC)/col-NAM-DAP-Seq(GSE60143)/Homer       RGTTRCGTRW
# 1005  REM16(ABI3VP1)/col-REM16-DAP-Seq(GSE60143)/Homer  DTTTTTSCCGSMAAA
#
#            P-value  Log P-value  q-value (Benjamini)  \
# 0     1.000000e-74       -170.6                  0.0
# 1     1.000000e-64       -147.5                  0.0
# 2     1.000000e-58       -134.4                  0.0
# 3     1.000000e-54       -124.4                  0.0
# 4     1.000000e-52       -119.7                  0.0
# ...            ...          ...                  ...
# 1001  1.000000e+00          0.0                  1.0
# 1002  1.000000e+00          0.0                  1.0
# 1003  1.000000e+00          0.0                  1.0
# 1004  1.000000e+00          0.0                  1.0
# 1005  1.000000e+00          0.0                  1.0
#
#       # of Target Sequences with Motif(of 7034)  \
# 0                                        3335.0
# 1                                        1904.0
# 2                                         876.0
# 3                                        1114.0
# 4                                        1002.0
# ...                                         ...
# 1001                                        0.0
# 1002                                     1358.0
# 1003                                     1094.0
# 1004                                      878.0
# 1005                                        0.0
#
#      % of Target Sequences with Motif  \
# 0                              47.41%
# 1                              27.07%
# 2                              12.45%
# 3                              15.84%
# 4                              14.25%
# ...                               ...
# 1001                            0.00%
# 1002                           19.31%
# 1003                           15.55%
# 1004                           12.48%
# 1005                            0.00%
#
#       # of Background Sequences with Motif(of 209085)  \
# 0                                             76817.8
# 1                                             39260.7
# 2                                             14693.5
# 3                                             20651.1
# 4                                             18183.1
# ...                                               ...
# 1001                                             88.2
# 1002                                          51301.3
# 1003                                          42398.3
# 1004                                          34644.6
# 1005                                              5.6
#
#      % of Background Sequences with Motif
# 0                                  36.74%
# 1                                  18.78%
# 2                                   7.03%
# 3                                   9.88%
# 4                                   8.70%
# ...                                   ...
# 1001                                0.04%
# 1002                               24.54%
# 1003                               20.28%
# 1004                               16.57%
# 1005                                0.00%
#
# [1006 rows x 9 columns]
