# %% [markdown]
# # Motifs that were enriched in categorized fragments responding to the depletion

# %%
import os
import numpy as np
import pandas as pd

# %%
def get_homer_top_motifs(filename, ntop=10):
    try:
        homer_df = pd.read_csv(filename, sep="\t")
        return homer_df.loc[:ntop-1, "Motif Name"].to_list()
    except FileNotFoundError:
        return [np.nan for _ in range(ntop)]


def get_meme_top_motifs(filename, ntop=10):
    meme_df = pd.read_csv(filename, sep="\t")
    return meme_df.loc[:ntop-1, "motif_ID"].to_list()

# %% [markdown]
# # Top 10 motifs for each ko lines by enhancer category

# %%
categories = ["peaks_vs_notpeaks", "responsive_vs_nonresponsive", "induced_vs_repressed", "repressed_vs_induced"]
ko_lines = ["ATF2", "CTCF", "FOXA1", "LEF1", "SCRT1", "TCF7L2", "16P12_1"]
store_dir = "../data/"

def get_homer_file(store_dir, ko, cat):
    homer_file = os.path.join(store_dir, ko, "homer", cat, f"knownResults.txt")
    return homer_file

def get_meme_file(store_dir, ko, cat):
    meme_file = os.path.join(store_dir, ko, "meme", cat, f"ame.tsv")
    return meme_file

def create_ko_specific_df(store_dir, ko, categories):
    data_dict = {f"{c}_{method}":[] for c in categories for method in ["homer", "meme"]}
    for c in categories:
        homer_file = get_homer_file(store_dir, ko, c)
        homer_motifs = get_homer_top_motifs(homer_file)
        data_dict[f"{c}_homer"] = homer_motifs
        meme_file = get_meme_file(store_dir, ko, c)
        meme_motifs = get_meme_top_motifs(meme_file)
        data_dict[f"{c}_meme"] = meme_motifs
    df = pd.DataFrame(data=data_dict, columns=[f"{c}_{method}" for c in categories for method in ["homer", "meme"]])
    return df

# %% [markdown]
# # ATF2

# %%
atf2_df = create_ko_specific_df(store_dir, ko_lines[0], categories)

# %%
atf2_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer   TYY1_HUMAN.H11MO.0.A
# 4                             YY1(Zf)/Promoter/Homer  CEBPG_HUMAN.H11MO.0.B
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   ATF4_HUMAN.H11MO.0.A
# 6       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer    FOS_HUMAN.H11MO.0.A
# 7                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer   JUNB_HUMAN.H11MO.0.A
# 8  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...   FOSB_HUMAN.H11MO.0.A
# 9      Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer  FOSL1_HUMAN.H11MO.0.A
#
#                    responsive_vs_nonresponsive_homer  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...
# 4                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 6       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer
# 7         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 8  CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512...
# 9     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer
#
#   responsive_vs_nonresponsive_meme  \
# 0              P53_HUMAN.H11MO.0.A
# 1              P63_HUMAN.H11MO.0.A
# 2              P73_HUMAN.H11MO.0.A
# 3             ATF4_HUMAN.H11MO.0.A
# 4            CEBPG_HUMAN.H11MO.0.B
# 5             ZIC1_HUMAN.H11MO.0.B
# 6              FEV_HUMAN.H11MO.0.B
# 7            SMAD3_HUMAN.H11MO.0.B
# 8             KLF6_HUMAN.H11MO.0.A
# 9              SUH_HUMAN.H11MO.0.A
#
#                           induced_vs_repressed_homer  \
# 0         Klf9(Zf)/GBM-Klf9-ChIP-Seq(GSE62211)/Homer
# 1      Rbpj1(?)/Panc1-Rbpj1-ChIP-Seq(GSE47459)/Homer
# 2  KLF10(Zf)/HEK293-KLF10.GFP-ChIP-Seq(GSE58341)/...
# 3        KLF6(Zf)/PDAC-KLF6-ChIP-Seq(GSE64557)/Homer
# 4                             Sp1(Zf)/Promoter/Homer
# 5         Klf4(Zf)/mES-Klf4-ChIP-Seq(GSE11431)/Homer
# 6     Sp2(Zf)/HEK293-Sp2.eGFP-ChIP-Seq(Encode)/Homer
# 7     VRN1(ABI3VP1)/col-VRN1-DAP-Seq(GSE60143)/Homer
# 8      KLF1(Zf)/HUDEP2-KLF1-CutnRun(GSE136251)/Homer
# 9      Sp5(Zf)/mES-Sp5.Flag-ChIP-Seq(GSE72989)/Homer
#
#   induced_vs_repressed_meme  \
# 0      TBX3_HUMAN.H11MO.0.C
# 1     TBX21_HUMAN.H11MO.0.A
# 2       SUH_HUMAN.H11MO.0.A
# 3      KLF5_HUMAN.H11MO.0.A
# 4      KLF1_HUMAN.H11MO.0.A
# 5     SALL4_HUMAN.H11MO.0.B
# 6      EGR2_HUMAN.H11MO.0.A
# 7      KLF9_HUMAN.H11MO.0.C
# 8      KLF6_HUMAN.H11MO.0.A
# 9      ITF2_HUMAN.H11MO.0.C
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer       P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer       P73_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer       P63_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...      ATF4_HUMAN.H11MO.0.A
# 4                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer     CEBPG_HUMAN.H11MO.0.B
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer       SRY_HUMAN.H11MO.0.B
# 6         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer       DBP_HUMAN.H11MO.0.B
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer      CDX1_HUMAN.H11MO.0.C
# 8           ZFX(Zf)/mES-Zfx-ChIP-Seq(GSE11431)/Homer     FOXO4_HUMAN.H11MO.0.C
# 9  ZNF711(Zf)/SHSY5Y-ZNF711-ChIP-Seq(GSE20673)/Homer     PRDM6_HUMAN.H11MO.0.C

# %% [markdown]
# # CTCF

# %%
ctcf_df = create_ko_specific_df(store_dir, ko_lines[1], categories)
ctcf_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...  CEBPG_HUMAN.H11MO.0.B
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer   ATF4_HUMAN.H11MO.0.A
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   TYY1_HUMAN.H11MO.0.A
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer  ZFP42_HUMAN.H11MO.0.A
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer  THAP1_HUMAN.H11MO.0.C
# 8                             YY1(Zf)/Promoter/Homer    ZFX_HUMAN.H11MO.0.A
# 9  CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512...  CEBPD_HUMAN.H11MO.0.C
#
#                    responsive_vs_nonresponsive_homer  \
# 0                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer
# 1       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 2       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer
# 3     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer
# 4        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer
# 5         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 6                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 7  CREB5(bZIP)/LNCaP-CREB5.V5-ChIP-Seq(GSE137775)...
# 8      Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer
# 9                JunD(bZIP)/K562-JunD-ChIP-Seq/Homer
#
#   responsive_vs_nonresponsive_meme  \
# 0            THAP1_HUMAN.H11MO.0.C
# 1              SP2_HUMAN.H11MO.0.A
# 2              SP3_HUMAN.H11MO.0.B
# 3             AP2B_HUMAN.H11MO.0.B
# 4             KLF3_HUMAN.H11MO.0.B
# 5             E2F4_HUMAN.H11MO.0.A
# 6             KLF6_HUMAN.H11MO.0.A
# 7            KLF12_HUMAN.H11MO.0.C
# 8              SP1_HUMAN.H11MO.0.A
# 9            MECP2_HUMAN.H11MO.0.C
#
#                           induced_vs_repressed_homer  \
# 0        FAR1(FAR1)/col-FAR1-DAP-Seq(GSE60143)/Homer
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 3         Klf9(Zf)/GBM-Klf9-ChIP-Seq(GSE62211)/Homer
# 4        Zic2(Zf)/ESC-Zic2-ChIP-Seq(SRP197560)/Homer
# 5   ANAC094(NAC)/col-ANAC094-DAP-Seq(GSE60143)/Homer
# 6  Unknown-ESC-element(?)/mES-Nanog-ChIP-Seq(GSE1...
# 7  IBL1(bHLH)/Seedling-IBL1-ChIP-Seq(GSE51120)/Homer
# 8  KLF14(Zf)/HEK293-KLF14.GFP-ChIP-Seq(GSE58341)/...
# 9   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
#
#   induced_vs_repressed_meme  \
# 0       SP2_HUMAN.H11MO.0.A
# 1       SP3_HUMAN.H11MO.0.B
# 2      ZIC1_HUMAN.H11MO.0.B
# 3      AP2B_HUMAN.H11MO.0.B
# 4      KLF3_HUMAN.H11MO.0.B
# 5      KLF6_HUMAN.H11MO.0.A
# 6     SALL4_HUMAN.H11MO.0.B
# 7      KLF1_HUMAN.H11MO.0.A
# 8     KLF12_HUMAN.H11MO.0.C
# 9      KLF5_HUMAN.H11MO.0.A
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer     CEBPG_HUMAN.H11MO.0.B
# 1       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer       SRY_HUMAN.H11MO.0.B
# 2                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer      ATF4_HUMAN.H11MO.0.A
# 3     TGA1(bZIP)/colamp-TGA1-DAP-Seq(GSE60143)/Homer     GATA3_HUMAN.H11MO.0.A
# 4        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer       DBP_HUMAN.H11MO.0.B
# 5  c-Jun-CRE(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/H...     PRDM6_HUMAN.H11MO.0.C
# 6     Atf2(bZIP)/3T3L1-Atf2-ChIP-Seq(GSE56872)/Homer      CDX1_HUMAN.H11MO.0.C
# 7                JunD(bZIP)/K562-JunD-ChIP-Seq/Homer     FOXK1_HUMAN.H11MO.0.A
# 8      Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer     ZN394_HUMAN.H11MO.0.C
# 9     Atf7(bZIP)/3T3L1-Atf7-ChIP-Seq(GSE56872)/Homer     NF2L1_HUMAN.H11MO.0.C

# %% [markdown]
# # FOXA1

# %%
foxa1_df = create_ko_specific_df(store_dir, ko_lines[2], categories)
foxa1_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...  CEBPG_HUMAN.H11MO.0.B
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer   ATF4_HUMAN.H11MO.0.A
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   ATF2_HUMAN.H11MO.0.B
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer  CREB1_HUMAN.H11MO.0.A
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer   ATF1_HUMAN.H11MO.0.B
# 8        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer   ATF3_HUMAN.H11MO.0.A
# 9     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer   TYY1_HUMAN.H11MO.0.A
#
#                    responsive_vs_nonresponsive_homer  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 3                JunD(bZIP)/K562-JunD-ChIP-Seq/Homer
# 4        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer
# 5   Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 6   Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 7  c-Jun-CRE(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/H...
# 8     TGA3(bZIP)/colamp-TGA3-DAP-Seq(GSE60143)/Homer
# 9     Atf2(bZIP)/3T3L1-Atf2-ChIP-Seq(GSE56872)/Homer
#
#   responsive_vs_nonresponsive_meme  \
# 0            THAP1_HUMAN.H11MO.0.C
# 1              SP2_HUMAN.H11MO.0.A
# 2              SP3_HUMAN.H11MO.0.B
# 3             KLF3_HUMAN.H11MO.0.B
# 4             E2F4_HUMAN.H11MO.0.A
# 5             AP2B_HUMAN.H11MO.0.B
# 6            MECP2_HUMAN.H11MO.0.C
# 7              SP1_HUMAN.H11MO.0.A
# 8             KLF6_HUMAN.H11MO.0.A
# 9            KLF12_HUMAN.H11MO.0.C
#
#                           induced_vs_repressed_homer  \
# 0     Atf7(bZIP)/3T3L1-Atf7-ChIP-Seq(GSE56872)/Homer
# 1  c-Jun-CRE(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/H...
# 2     Atf2(bZIP)/3T3L1-Atf2-ChIP-Seq(GSE56872)/Homer
# 3      BORIS(Zf)/K562-CTCFL-ChIP-Seq(GSE32465)/Homer
# 4  CRF10(AP2EREBP)/col100-CRF10-DAP-Seq(GSE60143)...
# 5                                  SeqBias: A/T bias
# 6                                 SeqBias: CG-repeat
# 7  CREB5(bZIP)/LNCaP-CREB5.V5-ChIP-Seq(GSE137775)...
# 8                JunD(bZIP)/K562-JunD-ChIP-Seq/Homer
# 9       STZ(C2H2)/colamp-STZ-DAP-Seq(GSE60143)/Homer
#
#   induced_vs_repressed_meme                        repressed_vs_induced_homer  \
# 0       SP3_HUMAN.H11MO.0.B      Elf4(ETS)/BMDM-Elf4-ChIP-Seq(GSE88699)/Homer
# 1       SP2_HUMAN.H11MO.0.A   ELF1(ETS)/Jurkat-ELF1-ChIP-Seq(SRA014231)/Homer
# 2      KLF6_HUMAN.H11MO.0.A       ETV4(ETS)/HepG2-ETV4-ChIP-Seq(ENCODE)/Homer
# 3      AP2B_HUMAN.H11MO.0.B      ELF3(ETS)/PDAC-ELF3-ChIP-Seq(GSE64557)/Homer
# 4      KLF3_HUMAN.H11MO.0.B      ELF5(ETS)/T47D-ELF5-ChIP-Seq(GSE30407)/Homer
# 5     SALL4_HUMAN.H11MO.0.B  GABPA(ETS)/Jurkat-GABPa-ChIP-Seq(GSE17954)/Homer
# 6      ZIC1_HUMAN.H11MO.0.B      Elk1(ETS)/Hela-Elk1-ChIP-Seq(GSE31477)/Homer
# 7     SRBP2_HUMAN.H11MO.0.B        Fli1(ETS)/CD8-FLI-ChIP-Seq(GSE20898)/Homer
# 8      KLF5_HUMAN.H11MO.0.A   SPDEF(ETS)/VCaP-SPDEF-ChIP-Seq(SRA014231)/Homer
# 9       SP4_HUMAN.H11MO.0.A   PU.1(ETS)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
#
#   repressed_vs_induced_meme
# 0       SRY_HUMAN.H11MO.0.B
# 1      CDX1_HUMAN.H11MO.0.C
# 2      PIT1_HUMAN.H11MO.0.C
# 3     FOXK1_HUMAN.H11MO.0.A
# 4     PRDM6_HUMAN.H11MO.0.C
# 5     PRRX2_HUMAN.H11MO.0.C
# 6     GATA3_HUMAN.H11MO.0.A
# 7       TBP_HUMAN.H11MO.0.A
# 8      SOX5_HUMAN.H11MO.0.C
# 9      IRF7_HUMAN.H11MO.0.C

# %% [markdown]
# # LEF1

# %%
lef1_df = create_ko_specific_df(store_dir, ko_lines[3], categories)
lef1_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   ATF4_HUMAN.H11MO.0.A
# 1                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer  CEBPG_HUMAN.H11MO.0.B
# 2       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer  CREB1_HUMAN.H11MO.0.A
# 3        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer   ATF2_HUMAN.H11MO.0.B
# 4                JunD(bZIP)/K562-JunD-ChIP-Seq/Homer   ATF1_HUMAN.H11MO.0.B
# 5      Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer   TYY1_HUMAN.H11MO.0.A
# 6     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer  THAP1_HUMAN.H11MO.0.C
# 7     TGA1(bZIP)/colamp-TGA1-DAP-Seq(GSE60143)/Homer   ATF3_HUMAN.H11MO.0.A
# 8  CREB5(bZIP)/LNCaP-CREB5.V5-ChIP-Seq(GSE137775)...  FOSL1_HUMAN.H11MO.0.A
# 9  c-Jun-CRE(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/H...    JUN_HUMAN.H11MO.0.A
#
#                    responsive_vs_nonresponsive_homer  \
# 0         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 1                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 2   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 5   Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 6   Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 7  Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer
# 8   AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
# 9       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
#
#   responsive_vs_nonresponsive_meme  \
# 0              P53_HUMAN.H11MO.0.A
# 1              P73_HUMAN.H11MO.0.A
# 2              P63_HUMAN.H11MO.0.A
# 3            CEBPG_HUMAN.H11MO.0.B
# 4             ATF4_HUMAN.H11MO.0.A
# 5            FOSL1_HUMAN.H11MO.0.A
# 6            FOSL2_HUMAN.H11MO.0.A
# 7             JUND_HUMAN.H11MO.0.A
# 8              JUN_HUMAN.H11MO.0.A
# 9             JUNB_HUMAN.H11MO.0.A
#
#                           induced_vs_repressed_homer  \
# 0   Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 1   Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 2  JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE360...
# 3  Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer
# 4      BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer
# 5        Fos(bZIP)/TSC-Fos-ChIP-Seq(GSE110950)/Homer
# 6     Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer
# 7       Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer
# 8   AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
# 9  Bach2(bZIP)/OCILy7-Bach2-ChIP-Seq(GSE44420)/Homer
#
#   induced_vs_repressed_meme  \
# 0     FOSL2_HUMAN.H11MO.0.A
# 1       FOS_HUMAN.H11MO.0.A
# 2      JUNB_HUMAN.H11MO.0.A
# 3      FOSB_HUMAN.H11MO.0.A
# 4       JUN_HUMAN.H11MO.0.A
# 5      JUND_HUMAN.H11MO.0.A
# 6     FOSL1_HUMAN.H11MO.0.A
# 7      E2F4_HUMAN.H11MO.0.A
# 8     NF2L1_HUMAN.H11MO.0.C
# 9     ZBT14_HUMAN.H11MO.0.C
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer       P53_HUMAN.H11MO.0.A
# 1                   p53(p53)/Saos-p53-ChIP-Seq/Homer       P73_HUMAN.H11MO.0.A
# 2   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer       P63_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...      LYL1_HUMAN.H11MO.0.A
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer      ATF4_HUMAN.H11MO.0.A
# 5  Tcfcp2l1(CP2)/mES-Tcfcp2l1-ChIP-Seq(GSE11431)/...     CEBPG_HUMAN.H11MO.0.B
# 6  ZNF416(Zf)/HEK293-ZNF416.GFP-ChIP-Seq(GSE58341...     SMAD3_HUMAN.H11MO.0.B
# 7                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer     NKX21_HUMAN.H11MO.0.A
# 8       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer     OLIG2_HUMAN.H11MO.0.B
# 9  CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512...     TGIF1_HUMAN.H11MO.0.A

# %% [markdown]
# # SCRT1

# %%
scrt1_df = create_ko_specific_df(store_dir, ko_lines[4], categories)
scrt1_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...  CEBPG_HUMAN.H11MO.0.B
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer   ATF4_HUMAN.H11MO.0.A
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   TYY1_HUMAN.H11MO.0.A
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer    ZFX_HUMAN.H11MO.0.A
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer  CEBPD_HUMAN.H11MO.0.C
# 8     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer  CEBPB_HUMAN.H11MO.0.A
# 9  Tcfcp2l1(CP2)/mES-Tcfcp2l1-ChIP-Seq(GSE11431)/...   ATF2_HUMAN.H11MO.0.B
#
#                    responsive_vs_nonresponsive_homer  \
# 0         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 1                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 2   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 5  Tcfcp2l1(CP2)/mES-Tcfcp2l1-ChIP-Seq(GSE11431)/...
# 6  ZNF416(Zf)/HEK293-ZNF416.GFP-ChIP-Seq(GSE58341...
# 7      Zfp809(Zf)/ES-Zfp809-ChIP-Seq(GSE70799)/Homer
# 8    RBFox2(?)/Heart-RBFox2-CLIP-Seq(GSE57926)/Homer
# 9                            NRF(NRF)/Promoter/Homer
#
#   responsive_vs_nonresponsive_meme  induced_vs_repressed_homer  \
# 0              P53_HUMAN.H11MO.0.A                         NaN
# 1              P63_HUMAN.H11MO.0.A                         NaN
# 2              P73_HUMAN.H11MO.0.A                         NaN
# 3            ZN449_HUMAN.H11MO.0.C                         NaN
# 4            SMAD3_HUMAN.H11MO.0.B                         NaN
# 5            SRBP1_HUMAN.H11MO.0.A                         NaN
# 6            THAP1_HUMAN.H11MO.0.C                         NaN
# 7             E2F3_HUMAN.H11MO.0.A                         NaN
# 8              SP3_HUMAN.H11MO.0.B                         NaN
# 9            SALL4_HUMAN.H11MO.0.B                         NaN
#
#   induced_vs_repressed_meme  \
# 0       P53_HUMAN.H11MO.0.A
# 1       P73_HUMAN.H11MO.0.A
# 2       P63_HUMAN.H11MO.0.A
# 3     ZBT48_HUMAN.H11MO.0.C
# 4       ZFX_HUMAN.H11MO.0.A
# 5     ZSC31_HUMAN.H11MO.0.C
# 6     ZN667_HUMAN.H11MO.0.C
# 7      COT1_HUMAN.H11MO.0.C
# 8      PAX6_HUMAN.H11MO.0.C
# 9      E2F4_HUMAN.H11MO.0.A
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer      ATF4_HUMAN.H11MO.0.A
# 1       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer     CEBPG_HUMAN.H11MO.0.B
# 2                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer     CEBPB_HUMAN.H11MO.0.A
# 3  CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512...       DBP_HUMAN.H11MO.0.B
# 4    HLF(bZIP)/HSC-HLF.Flag-ChIP-Seq(GSE69817)/Homer     CREB1_HUMAN.H11MO.0.A
# 5     Gata4(Zf)/Heart-Gata4-ChIP-Seq(GSE35151)/Homer       HLF_HUMAN.H11MO.0.C
# 6      Gata2(Zf)/K562-GATA2-ChIP-Seq(GSE18829)/Homer      ATF1_HUMAN.H11MO.0.B
# 7     Gata6(Zf)/HUG1N-GATA6-ChIP-Seq(GSE51936)/Homer     NKX31_HUMAN.H11MO.0.C
# 8  PBX1(Homeobox)/MCF7-PBX1-ChIP-Seq(GSE28007)/Homer     NKX61_HUMAN.H11MO.0.B
# 9     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer     GATA2_HUMAN.H11MO.0.A

# %% [markdown]
# # TCF7L2

# %%
tcf7l2_df = create_ko_specific_df(store_dir, ko_lines[5], categories)
tcf7l2_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer  CEBPG_HUMAN.H11MO.0.B
# 4  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...   ATF4_HUMAN.H11MO.0.A
# 5                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer   TYY1_HUMAN.H11MO.0.A
# 6       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer   ATF2_HUMAN.H11MO.0.B
# 7         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer  CREB1_HUMAN.H11MO.0.A
# 8     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer   ATF1_HUMAN.H11MO.0.B
# 9        TGA5(bZIP)/col-TGA5-DAP-Seq(GSE60143)/Homer  ZFP42_HUMAN.H11MO.0.A
#
#                    responsive_vs_nonresponsive_homer  \
# 0       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 1                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer
# 2       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer
# 3   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 4   Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 5   Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 6     Atf7(bZIP)/3T3L1-Atf7-ChIP-Seq(GSE56872)/Homer
# 7        Fos(bZIP)/TSC-Fos-ChIP-Seq(GSE110950)/Homer
# 8      Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer
# 9  CREB5(bZIP)/LNCaP-CREB5.V5-ChIP-Seq(GSE137775)...
#
#   responsive_vs_nonresponsive_meme  \
# 0            CEBPG_HUMAN.H11MO.0.B
# 1             ATF4_HUMAN.H11MO.0.A
# 2              P53_HUMAN.H11MO.0.A
# 3              P63_HUMAN.H11MO.0.A
# 4              JUN_HUMAN.H11MO.0.A
# 5             JUND_HUMAN.H11MO.0.A
# 6              P73_HUMAN.H11MO.0.A
# 7            FOSL2_HUMAN.H11MO.0.A
# 8            FOSL1_HUMAN.H11MO.0.A
# 9             FOSB_HUMAN.H11MO.0.A
#
#                           induced_vs_repressed_homer  \
# 0       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer
# 1       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 2                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer
# 3      c-Myc(bHLH)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 4        Fos(bZIP)/TSC-Fos-ChIP-Seq(GSE110950)/Homer
# 5   Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 6  JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE360...
# 7       Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer
# 8  Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer
# 9     Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer
#
#   induced_vs_repressed_meme  \
# 0     CEBPG_HUMAN.H11MO.0.B
# 1      ATF4_HUMAN.H11MO.0.A
# 2       JUN_HUMAN.H11MO.0.A
# 3     NF2L1_HUMAN.H11MO.0.C
# 4      BATF_HUMAN.H11MO.0.A
# 5     FOSL1_HUMAN.H11MO.0.A
# 6      JUND_HUMAN.H11MO.0.A
# 7     FOSL2_HUMAN.H11MO.0.A
# 8       SRY_HUMAN.H11MO.0.B
# 9      CDX1_HUMAN.H11MO.0.C
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0   Slug(Zf)/Mesoderm-Snai2-ChIP-Seq(GSE61475)/Homer     SNAI2_HUMAN.H11MO.0.A
# 1  E2A(bHLH),near_PU.1/Bcell-PU.1-ChIP-Seq(GSE215...     SNAI1_HUMAN.H11MO.0.C
# 2  Snail1(Zf)/LS174T-SNAIL1.HA-ChIP-Seq(GSE127183...     ASCL1_HUMAN.H11MO.0.A
# 3     Ascl2(bHLH)/ESC-Ascl2-ChIP-Seq(GSE97712)/Homer      TFE2_HUMAN.H11MO.0.A
# 4  Ascl1(bHLH)/NeuralTubes-Ascl1-ChIP-Seq(GSE5584...     MYOD1_HUMAN.H11MO.0.A
# 5     NGA4(ABI3VP1)/col-NGA4-DAP-Seq(GSE60143)/Homer      ITF2_HUMAN.H11MO.0.C
# 6  NeuroG2(bHLH)/Fibroblast-NeuroG2-ChIP-Seq(GSE7...      NDF2_HUMAN.H11MO.0.B
# 7   Ptf1a(bHLH)/Panc1-Ptf1a-ChIP-Seq(GSE47459)/Homer      HTF4_HUMAN.H11MO.0.A
# 8       ARF16(ARF)/col-ARF16-DAP-Seq(GSE60143)/Homer     BHA15_HUMAN.H11MO.0.B
# 9        ZEB1(Zf)/PDAC-ZEB1-ChIP-Seq(GSE64557)/Homer      MYOG_HUMAN.H11MO.0.B

# %% [markdown]
# # 16p12.1

# %%
cnv_df = create_ko_specific_df(store_dir, ko_lines[6], categories)
cnv_df
# Out:
#                              peaks_vs_notpeaks_homer peaks_vs_notpeaks_meme  \
# 0   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer    P53_HUMAN.H11MO.0.A
# 1         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer    P63_HUMAN.H11MO.0.A
# 2                   p53(p53)/Saos-p53-ChIP-Seq/Homer    P73_HUMAN.H11MO.0.A
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...  CEBPG_HUMAN.H11MO.0.B
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer   ATF4_HUMAN.H11MO.0.A
# 5       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer   TYY1_HUMAN.H11MO.0.A
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer  ZFP42_HUMAN.H11MO.0.A
# 7       Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer  CREB1_HUMAN.H11MO.0.A
# 8     NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer   ATF2_HUMAN.H11MO.0.B
# 9                             YY1(Zf)/Promoter/Homer  CEBPD_HUMAN.H11MO.0.C
#
#                    responsive_vs_nonresponsive_homer  \
# 0         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 1                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 2   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...
# 4           ZFX(Zf)/mES-Zfx-ChIP-Seq(GSE11431)/Homer
# 5  ZNF711(Zf)/SHSY5Y-ZNF711-ChIP-Seq(GSE20673)/Homer
# 6         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 7  Tcfcp2l1(CP2)/mES-Tcfcp2l1-ChIP-Seq(GSE11431)/...
# 8       Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 9                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer
#
#   responsive_vs_nonresponsive_meme  \
# 0              ZFX_HUMAN.H11MO.0.A
# 1              P53_HUMAN.H11MO.0.A
# 2              P73_HUMAN.H11MO.0.A
# 3              P63_HUMAN.H11MO.0.A
# 4             AP2B_HUMAN.H11MO.0.B
# 5              SP2_HUMAN.H11MO.0.A
# 6            THAP1_HUMAN.H11MO.0.C
# 7              SP3_HUMAN.H11MO.0.B
# 8             ZIC1_HUMAN.H11MO.0.B
# 9            SRBP2_HUMAN.H11MO.0.B
#
#                           induced_vs_repressed_homer  \
# 0         p53(p53)/Saos-p53-ChIP-Seq(GSE15780)/Homer
# 1                   p53(p53)/Saos-p53-ChIP-Seq/Homer
# 2   p73(p53)/Trachea-p73-ChIP-Seq(PRJNA310161)/Homer
# 3  p63(p53)/Keratinocyte-p63-ChIP-Seq(GSE17611)/H...
# 4         p53(p53)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
# 5  Nrf2(bZIP)/Lymphoblast-Nrf2-ChIP-Seq(GSE37589)...
# 6     NF-E2(bZIP)/K562-NFE2-ChIP-Seq(GSE31477)/Homer
# 7  Bach2(bZIP)/OCILy7-Bach2-ChIP-Seq(GSE44420)/Homer
# 8        Fos(bZIP)/TSC-Fos-ChIP-Seq(GSE110950)/Homer
# 9      c-Myc(bHLH)/mES-cMyc-ChIP-Seq(GSE11431)/Homer
#
#   induced_vs_repressed_meme  \
# 0       P53_HUMAN.H11MO.0.A
# 1       P73_HUMAN.H11MO.0.A
# 2       P63_HUMAN.H11MO.0.A
# 3      CDX1_HUMAN.H11MO.0.C
# 4       SRY_HUMAN.H11MO.0.B
# 5      HXA9_HUMAN.H11MO.0.B
# 6     PRDM6_HUMAN.H11MO.0.C
# 7     HXB13_HUMAN.H11MO.0.A
# 8      PIT1_HUMAN.H11MO.0.C
# 9      ANDR_HUMAN.H11MO.0.A
#
#                           repressed_vs_induced_homer repressed_vs_induced_meme
# 0           ZFX(Zf)/mES-Zfx-ChIP-Seq(GSE11431)/Homer       ZFX_HUMAN.H11MO.0.A
# 1  ERF8(AP2EREBP)/colamp-ERF8-DAP-Seq(GSE60143)/H...      AP2B_HUMAN.H11MO.0.B
# 2      Zfp281(Zf)/ES-Zfp281-ChIP-Seq(GSE81042)/Homer      KLF6_HUMAN.H11MO.0.A
# 3         Zic3(Zf)/mES-Zic3-ChIP-Seq(GSE37889)/Homer       SP2_HUMAN.H11MO.0.A
# 4  ERF9(AP2EREBP)/colamp-ERF9-DAP-Seq(GSE60143)/H...       SP3_HUMAN.H11MO.0.B
# 5  ZNF711(Zf)/SHSY5Y-ZNF711-ChIP-Seq(GSE20673)/Homer     PATZ1_HUMAN.H11MO.0.C
# 6                  AARE(HLH)/mES-cMyc-ChIP-Seq/Homer     SALL4_HUMAN.H11MO.0.B
# 7    RKD2(RWPRK)/colamp-RKD2-DAP-Seq(GSE60143)/Homer      ZIC1_HUMAN.H11MO.0.B
# 8  Rap210(AP2EREBP)/col-Rap210-DAP-Seq(GSE60143)/...      ITF2_HUMAN.H11MO.0.C
# 9  AT1G12630(AP2EREBP)/colamp-AT1G12630-DAP-Seq(G...     SRBP2_HUMAN.H11MO.0.B
